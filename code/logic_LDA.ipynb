# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_rows', 500000)
logic_df = pd.read_csv('logic_df_final.csv', index_col=0)

# %%
logic_df.head()
# Out:
#                album         artist  \
# 0  Undeniable (2012)  Young Sinatra
# 1  Undeniable (2012)  Young Sinatra
# 2  Undeniable (2012)  Young Sinatra
# 3  Undeniable (2012)  Young Sinatra
# 4  Undeniable (2012)  Young Sinatra
#
#                                                             lyric        song
# 0  Yeah; pass the mic before I jack it like gore-tex               Disgusting
# 1  Bust like raw sex, rappers suck like vortex                     Disgusting
# 2  The life of a Don- We living like kings, and killing our pawns  Disgusting
# 3  Boy, the seconds it's on - don't know where we going            Disgusting
# 4  I'm flowing and killing this shit from dusk till dawn           Disgusting

# %%
# gensim
from gensim import corpora, models, similarities, matutils
# sklearn
from sklearn import datasets
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
# logging for gensim (set to INFO)
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %% [markdown]
# # text preprocessing

# %%
logic_df.lyric = logic_df.lyric.str.replace(r'([^\s\w]|_)+', '')

# %%
logic_df.lyric = logic_df.lyric.str.lower()

# %%
logic_df.head()
# Out:
#                album         artist  \
# 0  Undeniable (2012)  Young Sinatra
# 1  Undeniable (2012)  Young Sinatra
# 2  Undeniable (2012)  Young Sinatra
# 3  Undeniable (2012)  Young Sinatra
# 4  Undeniable (2012)  Young Sinatra
#
#                                                           lyric        song
# 0  yeah pass the mic before i jack it like goretex               Disgusting
# 1  bust like raw sex rappers suck like vortex                    Disgusting
# 2  the life of a don we living like kings and killing our pawns  Disgusting
# 3  boy the seconds its on  dont know where we going              Disgusting
# 4  im flowing and killing this shit from dusk till dawn          Disgusting

# %%
logic_df.drop(["artist", "album", "song"], axis=1, inplace=True)

# %%
logic_df.head()
# Out:
#                                                           lyric
# 0  yeah pass the mic before i jack it like goretex
# 1  bust like raw sex rappers suck like vortex
# 2  the life of a don we living like kings and killing our pawns
# 3  boy the seconds its on  dont know where we going
# 4  im flowing and killing this shit from dusk till dawn

# %%
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')

logic_df['tokenized_lyrics'] = logic_df.lyric.apply(word_tokenize) 
logic_df.head()
# Out:
# [nltk_data] Downloading package punkt to /Users/Benjamin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
#                                                           lyric  \
# 0  yeah pass the mic before i jack it like goretex
# 1  bust like raw sex rappers suck like vortex
# 2  the life of a don we living like kings and killing our pawns
# 3  boy the seconds its on  dont know where we going
# 4  im flowing and killing this shit from dusk till dawn
#
#                                                              tokenized_lyrics
# 0  [yeah, pass, the, mic, before, i, jack, it, like, goretex]
# 1  [bust, like, raw, sex, rappers, suck, like, vortex]
# 2  [the, life, of, a, don, we, living, like, kings, and, killing, our, pawns]
# 3  [boy, the, seconds, its, on, dont, know, where, we, going]
# 4  [im, flowing, and, killing, this, shit, from, dusk, till, dawn]

# %%
logic_df.lyric
# Out:
# 0       yeah pass the mic before i jack it like goretex
# 1       bust like raw sex rappers suck like vortex
# 2       the life of a don we living like kings and killing our pawns
# 3       boy the seconds its on  dont know where we going
# 4       im flowing and killing this shit from dusk till dawn
# 5       just had sex with a middle eastern girl the pussy was bomb
# 6       that last line made no sense like these rappers careers
# 7       but i make dollars cause im all about the fiscal year
# 8       yeah you dont like me ill conjure up and summon all your fears
# 9       you wanna fight me ill woop my own ass before you get here
# 10      wanna write me and tell me that my rhymes suck
# 11      bitch i dont give a fuck ill stab you in the gut call it a tummy tuck
# 12      you can ask my ex i bust quicker than two techs
# 13      caressed by a kid with category 5 tourettes
# 14      in other words i squeeze with ease dot my is and cross my ts
# 15      im a perfectionist the lesson is fuck everyone assessing this
# 16      its hiphop not to be taken literally
# 17      however on the light of note i stayed with bills like hilary
# 18      my flow convects murder subjects with little respect
# 19      best protect your neck before you play my tape better inspect the deck
# 20      fuck every other rapper forever ever forever since the dawn of time
# 21      sike im not that much of a dick when i rhyme
# 22      on another level like duplex bust heads like suplex
# 23      slaughter mcs then ask whos next
# 24      i murdered my manager chris last night
# 25      we exchanged a couple words he said some things i didnt like
# 26      i said okay then punched him in the face with a butcher knife
# 27      i want more like ashton kutchers wife
# 28      now can you feel it they wont sinatra
# 29      gimme what i want so fuck it im a steal it
# 30      ill dilapidate you grab the butter knife and decapitate you
# 31      yeah thats what i said  huh and bitch i did it
# 32      we all have thoughts like this im just willing to admit it
# 33      i would never act upon these thoughts now dont you get it
# 34      its like when a gentleman sees the baddest bitch and thinks id hit it
# 35      but he never says it ill dump your body in a dessert
# 36      its the wrath of a psychopath clutching a razor blade in a bath
# 37      having his last laugh anticipating a gash the other night i murdered captain crunch
# 38      right in front of toucan sam and a whole damn bunch
# 39      thats life what can i say im a cereal killer venereal dealer
# 40      and yes you know they aint none other iller
# 41      its logic
# 42      dead presidents iii not to be confused with growing pains iii
# 43      logic this logic that logic sick logic wack
# 44      logic just dont give a fuck rattpack
# 45      so many people think that rap is they calling stop it just cease
# 46      gotacapeashe this is my house you fuckers just lease
# 47      waitin on a record deal thats never cumming like a priest
# 48      black and white like a nun
# 49      these upandcomers our sun
# 50      like the break of dawn
# 51      so follow your father like an apostle paint pictures like a picasso while bitches uncover my fossil
# 52      never knowin whats gon follow
# 53      however we never wallow in our sorrow
# 54      just pray for tomorrow
# 55      at times my heart could be hallow
# 56      emotions forced to be swallowed
# 57      while neighborhood cats blast star gas like the apollo
# 58      this is just a simple reminder as my lyrics force you to ponder
# 59      lifes a bitch and i heard shell fuck you so im trying to find her
# 60      one moment shell love you then swallow you whole like an anaconda
# 61      the bitch is kinky kind of
# 62      so with the lift of a pinky imma
# 63      dominate the world like my name was brain
# 64      spit flame like propane
# 65      bitches i overcame you know the name
# 66      ink in my veins inflames and spew on the page to numb the pain like novocain muthafucker
# 67      im out for presidents to represent me get money
# 68      im out for presidents to represent me get money
# 69      im out for presidents to represent me get money
# 70      im out for dead fucking presidents to represent me
# 71      im out for presidents to represent me get money
# 72      im out for presidents to represent me get money
# 73      im out for presidents to represent me get money
# 74      im out for dead fucking presidents to represent me
# 75      allow me to kill it off the brink like no traffic
# 76      murderin every demographic
# 77      paint a picture using only blood to make sure that its graphic
# 78      rip the mic to set the example
# 79      while all these muthafuckers testin my patience like blood samples
# 80      constant thoughts of suicide
# 81      where living in an era thats do or die
# ...
# 5863    writin words to the beats
# 5864    each one teach one yeah im tryna reach one
# 5865    who the beast one
# 5866    that be me on the top to the east one
# 5867    tell me how you really wanna do it right now time to murder this
# 5868    shout out everybody no fuckin around aint heard of this
# 5869    heard of us we aint goin nowhere its a herd of us
# 5870    hold up roll up
# 5871    levitated like im david blaine
# 5872    livin a dream like im david aames
# 5873    talk all you want we are not the same
# 5874    step in the spot now they know the name
# 5875    sold more albums my first week than harry styles and katy perry
# 5876    if that aint a sign of the times
# 5877    then i dont know what is man this shit is scary
# 5878    cause bitch ive been blowin up like c4
# 5879    and im 3 for 3 like a free throw
# 5880    anybody hatin on the boy take a step back and then deepthroat
# 5881    now my phone blowin up like ring
# 5882    like ring ring ring ring ring ring ring ring ring ring ring
# 5883    that kevin durant im a champion
# 5884    check the numbers im a champion
# 5885    cant sleep on the boy anymore
# 5886    but the haters that love to hate gon pop an ambien
# 5887    star lord champion
# 5888    know the name now they know the alias thats for sure
# 5889    gave em 44 now heres 44 more
# Name: lyric, dtype: object

# %%
#create a list of all the unique words in the lyrics

unique_words = []
for line in logic_df.lyric:
        if line not in unique_words:
            unique_words.append(line)
        else:
            pass

# %%
from nltk.corpus import stopwords

# %%
stopwords = stopwords.words('english')+["woo","wizard", "rick", "morty", "life", "sinatra","ring", " hold", "wait", "tell", "whats", "take", "one", "come", "man", "around", "said", "yall", "bobby", "logic", "young sinatra", "go", "gotta", "ive", "feeling","back", "let", "ima", "wanna", "never", "make", "thats", "let", "cant", "cause", "got", "oh", "really", "want","get", "know", "way", "based", "regarding", "like", "yeah", "shit", "fuck", "im", "aint", "feel", "right", "em", "im", 'dont', "right"]

# %%
# Create a CountVectorizer for parsing/counting words
count_vectorizer = CountVectorizer(ngram_range=(1,2),  
                                   stop_words=stopwords, token_pattern="\\b[a-z][a-z]+\\b")
count_vectorizer.fit(unique_words)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), preprocessor=None,
#         stop_words=['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs',...arding', 'like', 'yeah', 'shit', 'fuck', 'im', 'aint', 'feel', 'right', 'em', 'im', 'dont', 'right'],
#         strip_accents=None, token_pattern='\\b[a-z][a-z]+\\b',
#         tokenizer=None, vocabulary=None)

# %%
counts = count_vectorizer.transform(unique_words).transpose()

# %%
counts
# Out:
# <13795x4689 sparse matrix of type '<class 'numpy.int64'>'
# 	with 25228 stored elements in Compressed Sparse Column format>

# %%
# Convert sparse matrix of counts to a gensim corpus
corpus = matutils.Sparse2Corpus(counts)

# %%
id2word = dict((v, k) for k, v in count_vectorizer.vocabulary_.items())

# %%
count_vectorizer.vocabulary_.items()
# Out:
# dict_items([('pass', 8658), ('mic', 7568), ('jack', 6098), ('goretex', 4884), ('pass mic', 8660), ('mic jack', 7572), ('jack goretex', 6099), ('bust', 1524), ('raw', 9532), ('sex', 10465), ('rappers', 9472), ('suck', 11513), ('vortex', 12871), ('bust raw', 1531), ('raw sex', 9535), ('sex rappers', 10471), ('rappers suck', 9486), ('suck vortex', 11515), ('living', 6839), ('kings', 6342), ('killing', 6310), ('pawns', 8683), ('living kings', 6858), ('kings killing', 6343), ('killing pawns', 6314), ('boy', 1272), ('seconds', 10247), ('going', 4765), ('boy seconds', 1298), ('seconds going', 10248), ('flowing', 4189), ('dusk', 3178), ('till', 12150), ('dawn', 2562), ('flowing killing', 4191), ('killing dusk', 6312), ('dusk till', 3179), ('till dawn', 12156), ('middle', 7593), ('eastern', 3216), ('girl', 4590), ('pussy', 9316), ('bomb', 1175), ('sex middle', 10470), ('middle eastern', 7595), ('eastern girl', 3217), ('girl pussy', 4614), ('pussy bomb', 9317), ('last', 6465), ('line', 6695), ('made', 7157), ('sense', 10416), ('careers', 1675), ('last line', 6472), ('line made', 6697), ('made sense', 7176), ('sense rappers', 10419), ('rappers careers', 9477), ('dollars', 2987), ('fiscal', 4110), ('year', 13628), ('dollars fiscal', 2990), ('fiscal year', 4111), ('ill', 5841), ('conjure', 2156), ('summon', 11533), ('fears', 3873), ('ill conjure', 5848), ('conjure summon', 2157), ('summon fears', 11534), ('fight', 3966), ('woop', 13363), ('ass', 471), ('fight ill', 3972), ('ill woop', 5876), ('woop ass', 13364), ('write', 13558), ('rhymes', 9848), ('write rhymes', 13566), ('rhymes suck', 9852), ('bitch', 944), ('give', 4632), ('stab', 11207), ('gut', 5048), ('call', 1574), ('tummy', 12518), ('tuck', 12514), ('bitch give', 961), ('give ill', 4653), ('ill stab', 5871), ('stab gut', 11208), ('gut call', 5049), ('call tummy', 1593), ('tummy tuck', 12519), ('ask', 454), ('ex', 3652), ('quicker', 9380), ('two', 12552), ('techs', 11808), ('ask ex', 457), ('ex bust', 3653), ('bust quicker', 1530), ('quicker two', 9382), ('two techs', 12558), ('caressed', 1678), ('kid', 6271), ('category', 1717), ('tourettes', 12333), ('caressed kid', 1679), ('kid category', 6272), ('category tourettes', 1718), ('words', 13378), ('squeeze', 11204), ('ease', 3208), ('dot', 3035), ('cross', 2406), ('ts', 12513), ('words squeeze', 13385), ('squeeze ease', 11205), ('ease dot', 3209), ('dot cross', 3036), ('cross ts', 2407), ('perfectionist', 8800), ('lesson', 6606), ('everyone', 3582), ('assessing', 488), ('perfectionist lesson', 8801), ('lesson everyone', 6607), ('everyone assessing', 3583), ('hiphop', 5472), ('taken', 11672), ('literally', 6753), ('hiphop taken', 5477), ('taken literally', 11673), ('however', 5710), ('light', 6664), ('note', 8356), ('stayed', 11302), ('bills', 925), ('hilary', 5465), ('however light', 5711), ('light note', 6671), ('note stayed', 8357), ('stayed bills', 11304), ('bills hilary', 927), ('flow', 4154), ('convects', 2195), ('murder', 8022), ('subjects', 11495), ('little', 6756), ('respect', 9787), ('flow convects', 4163), ('convects murder', 2196), ('murder subjects', 8031), ('subjects little', 11496), ('little respect', 6770), ('best', 831), ('protect', 9245), ('neck', 8174), ('play', 8951), ('tape', 11755), ('better', 850), ('inspect', 6022), ('deck', 2665), ('best protect', 841), ('protect neck', 9246), ('neck play', 8176), ('play tape', 8959), ('tape better', 11756), ('better inspect', 865), ('inspect deck', 6023), ('every', 3467), ('rapper', 9465), ('forever', 4275), ('ever', 3444), ('since', 10683), ('time', 12175), ('every rapper', 3491), ('rapper forever', 9469), ('forever ever', 4278), ('ever forever', 3450), ('forever since', 4281), ('since dawn', 10686), ('dawn time', 2564), ('sike', 10667), ('much', 7990), ('dick', 2832), ('rhyme', 9842), ('sike much', 10668), ('much dick', 7996), ('dick rhyme', 2835), ('another', 317), ('level', 6625), ('duplex', 3174), ('heads', 5271), ('suplex', 11554), ('another level', 327), ('level duple ...

# %%
len(id2word)
# Out:
# 13795

# %%
lda = models.LdaModel(corpus=corpus, num_topics=2, minimum_probability=0.2, id2word=id2word, passes=4)
# Out:
# 2018-05-30 14:53:38,835 : INFO : using symmetric alpha at 0.5
# 2018-05-30 14:53:38,837 : INFO : using symmetric eta at 0.5
# 2018-05-30 14:53:38,842 : INFO : using serial LDA version on this node
# 2018-05-30 14:53:38,849 : INFO : running online (multi-pass) LDA training, 2 topics, 4 passes over the supplied corpus of 4689 documents, updating model once every 2000 documents, evaluating perplexity every 4689 documents, iterating 50x with a convergence threshold of 0.001000
# 2018-05-30 14:53:38,850 : WARNING : too few updates, training might not converge; consider increasing the number of passes or iterations to improve accuracy
# 2018-05-30 14:53:38,866 : INFO : PROGRESS: pass 0, at document #2000/4689
# 2018-05-30 14:53:40,500 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:40,506 : INFO : topic #0 (0.500): 0.005*"love" + 0.003*"time" + 0.003*"day" + 0.003*"kai" + 0.003*"world" + 0.002*"bitch" + 0.002*"people" + 0.002*"money" + 0.002*"yes" + 0.002*"imma"
# 2018-05-30 14:53:40,508 : INFO : topic #1 (0.500): 0.003*"girl" + 0.003*"thomas" + 0.003*"time" + 0.002*"think" + 0.002*"love" + 0.002*"wonder" + 0.002*"everything" + 0.002*"give" + 0.002*"people" + 0.002*"another"
# 2018-05-30 14:53:40,509 : INFO : topic diff=1.267329, rho=1.000000
# 2018-05-30 14:53:40,525 : INFO : PROGRESS: pass 0, at document #4000/4689
# 2018-05-30 14:53:41,919 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:41,925 : INFO : topic #0 (0.500): 0.004*"world" + 0.004*"black" + 0.003*"love" + 0.003*"people" + 0.003*"money" + 0.003*"time" + 0.003*"every" + 0.002*"day" + 0.002*"live" + 0.002*"white"
# 2018-05-30 14:53:41,927 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.003*"give" + 0.003*"god" + 0.003*"think" + 0.003*"need" + 0.003*"mind" + 0.003*"people" + 0.003*"everything" + 0.003*"gonna" + 0.002*"see"
# 2018-05-30 14:53:41,928 : INFO : topic diff=1.028471, rho=0.707107
# 2018-05-30 14:53:42,426 : INFO : -10.586 per-word bound, 1537.2 perplexity estimate based on a held-out corpus of 689 documents with 3799 words
# 2018-05-30 14:53:42,427 : INFO : PROGRESS: pass 0, at document #4689/4689
# 2018-05-30 14:53:42,859 : INFO : merging changes from 689 documents into a model of 4689 documents
# 2018-05-30 14:53:42,864 : INFO : topic #0 (0.500): 0.003*"bitch" + 0.003*"good" + 0.003*"uh" + 0.003*"money" + 0.003*"world" + 0.003*"love" + 0.002*"mean" + 0.002*"young" + 0.002*"rap" + 0.002*"black"
# 2018-05-30 14:53:42,866 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.003*"mind" + 0.003*"give" + 0.003*"think" + 0.003*"ever" + 0.003*"bitch" + 0.003*"real" + 0.003*"boy" + 0.003*"say" + 0.002*"finna"
# 2018-05-30 14:53:42,867 : INFO : topic diff=0.784831, rho=0.577350
# 2018-05-30 14:53:42,881 : INFO : PROGRESS: pass 1, at document #2000/4689
# 2018-05-30 14:53:43,667 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:43,673 : INFO : topic #0 (0.500): 0.004*"love" + 0.003*"world" + 0.003*"bitch" + 0.003*"day" + 0.003*"money" + 0.003*"time" + 0.002*"uh" + 0.002*"good" + 0.002*"mean" + 0.002*"yes"
# 2018-05-30 14:53:43,675 : INFO : topic #1 (0.500): 0.003*"everybody" + 0.003*"give" + 0.003*"think" + 0.003*"everything" + 0.003*"girl" + 0.003*"mind" + 0.002*"people" + 0.002*"say" + 0.002*"ever" + 0.002*"hold"
# 2018-05-30 14:53:43,677 : INFO : topic diff=0.559360, rho=0.479767
# 2018-05-30 14:53:43,691 : INFO : PROGRESS: pass 1, at document #4000/4689
# 2018-05-30 14:53:44,362 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:44,369 : INFO : topic #0 (0.500): 0.004*"world" + 0.004*"black" + 0.003*"love" + 0.003*"money" + 0.003*"time" + 0.003*"every" + 0.003*"day" + 0.002*"people" + 0.002*"uh" + 0.002*"good"
# 2018-05-30 14:53:44,370 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"god" + 0.003*"think" + 0.003*"mind" + 0.003*"everything" + 0.003*"need" + 0.003*"people" + 0.002*"gonna" + 0.002*"see"
# 2018-05-30 14:53:44,371 : INFO : topic diff=0.481857, rho=0.479767
# 2018-05-30 14:53:44,738 : INFO : -9.423 per-word bound, 686.5 perplexity estimate based on a held-out corpus of 689 documents with 3799 words
# 2018-05-30 14:53:44,739 : INFO : PROGRESS: pass 1, at document #4689/4689
# 2018-05-30 14:53:44,944 : INFO : merging changes from 689 documents into a model of 4689 documents
# 2018-05-30 14:53:44,950 : INFO : topic #0 (0.500): 0.003*"good" + 0.003*"bitch" + 0.003*"uh" + 0.003*"world" + 0.003*"love" + 0.003*"money" + 0.002*"mean" + 0.002*"black" + 0.002*"day" + 0.002*"young"
# 2018-05-30 14:53:44,952 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"mind" + 0.003*"think" + 0.003*"boy" + 0.003*"ever" + 0.003*"bitch" + 0.003*"finna" + 0.003*"everything" + 0.003*"god"
# 2018-05-30 14:53:44,953 : INFO : topic diff=0.418714, rho=0.479767
# 2018-05-30 14:53:44,967 : INFO : PROGRESS: pass 2, at document #2000/4689
# 2018-05-30 14:53:45,598 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:45,603 : INFO : topic #0 (0.500): 0.004*"love" + 0.003*"world" + 0.003*"day" + 0.003*"time" + 0.003*"bitch" + 0.003*"money" + 0.003*"uh" + 0.002*"good" + 0.002*"mean" + 0.002*"every"
# 2018-05-30 14:53:45,605 : INFO : topic #1 (0.500): 0.003*"everybody" + 0.003*"give" + 0.003*"think" + 0.003*"everything" + 0.003*"girl" + 0.003*"mind" + 0.003*"people" + 0.002*"ever" + 0.002*"hold" + 0.002*"say"
# 2018-05-30 14:53:45,607 : INFO : topic diff=0.442055, rho=0.432560
# 2018-05-30 14:53:45,619 : INFO : PROGRESS: pass 2, at document #4000/4689
# 2018-05-30 14:53:46,160 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:46,165 : INFO : topic #0 (0.500): 0.004*"world" + 0.004*"black" + 0.003*"love" + 0.003*"money" + 0.003*"time" + 0.003*"every" + 0.003*"day" + 0.002*"good" + 0.002*"uh" + 0.002*"people"
# 2018-05-30 14:53:46,167 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"god" + 0.003*"think" + 0.003*"everything" + 0.003*"mind" + 0.003*"people" + 0.003*"need" + 0.002*"gonna" + 0.002*"boy"
# 2018-05-30 14:53:46,169 : INFO : topic diff=0.396728, rho=0.432560
# 2018-05-30 14:53:46,436 : INFO : -9.276 per-word bound, 619.9 perplexity estimate based on a held-out corpus of 689 documents with 3799 words
# 2018-05-30 14:53:46,437 : INFO : PROGRESS: pass 2, at document #4689/4689
# 2018-05-30 14:53:46,587 : INFO : merging changes from 689 documents into a model of 4689 documents
# 2018-05-30 14:53:46,593 : INFO : topic #0 (0.500): 0.003*"good" + 0.003*"bitch" + 0.003*"world" + 0.003*"uh" + 0.003*"love" + 0.003*"money" + 0.002*"mean" + 0.002*"black" + 0.002*"day" + 0.002*"time"
# 2018-05-30 14:53:46,594 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"think" + 0.003*"mind" + 0.003*"boy" + 0.003*"everything" + 0.003*"ever" + 0.003*"bitch" + 0.003*"god" + 0.003*"finna"
# 2018-05-30 14:53:46,596 : INFO : topic diff=0.338505, rho=0.432560
# 2018-05-30 14:53:46,609 : INFO : PROGRESS: pass 3, at document #2000/4689
# 2018-05-30 14:53:47,143 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:47,148 : INFO : topic #0 (0.500): 0.003*"love" + 0.003*"world" + 0.003*"day" + 0.003*"time" + 0.003*"bitch" + 0.003*"money" + 0.003*"uh" + 0.002*"good" + 0.002*"mean" + 0.002*"every"
# 2018-05-30 14:53:47,150 : INFO : topic #1 (0.500): 0.003*"everybody" + 0.003*"give" + 0.003*"think" + 0.003*"everything" + 0.003*"girl" + 0.003*"people" + 0.002*"mind" + 0.002*"god" + 0.002*"ever" + 0.002*"bitch"
# 2018-05-30 14:53:47,151 : INFO : topic diff=0.377785, rho=0.397010
# 2018-05-30 14:53:47,164 : INFO : PROGRESS: pass 3, at document #4000/4689
# 2018-05-30 14:53:47,668 : INFO : merging changes from 2000 documents into a model of 4689 documents
# 2018-05-30 14:53:47,674 : INFO : topic #0 (0.500): 0.004*"black" + 0.004*"world" + 0.003*"love" + 0.003*"money" + 0.003*"time" + 0.003*"every" + 0.003*"day" + 0.002*"good" + 0.002*"uh" + 0.002*"live"
# 2018-05-30 14:53:47,675 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"god" + 0.003*"think" + 0.003*"everything" + 0.003*"people" + 0.003*"mind" + 0.003*"need" + 0.002*"boy" + 0.002*"could"
# 2018-05-30 14:53:47,677 : INFO : topic diff=0.345316, rho=0.397010
# 2018-05-30 14:53:47,935 : INFO : -9.210 per-word bound, 592.3 perplexity estimate based on a held-out corpus of 689 documents with 3799 words
# 2018-05-30 14:53:47,939 : INFO : PROGRESS: pass 3, at document #4689/4689
# 2018-05-30 14:53:48,100 : INFO : merging changes from 689 documents into a model of 4689 documents
# 2018-05-30 14:53:48,105 : INFO : topic #0 (0.500): 0.003*"good" + 0.003*"bitch" + 0.003*"world" + 0.003*"uh" + 0.003*"love" + 0.003*"money" + 0.002*"black" + 0.002*"mean" + 0.002*"day" + 0.002*"time"
# 2018-05-30 14:53:48,107 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"think" + 0.003*"mind" + 0.003*"everything" + 0.003*"boy" + 0.003*"god" + 0.003*"ever" + 0.003*"people" + 0.003*"finna"
# 2018-05-30 14:53:48,108 : INFO : topic diff=0.295232, rho=0.397010

# %%
lda.print_topics()
# Out:
# 2018-05-30 14:53:48,119 : INFO : topic #0 (0.500): 0.003*"good" + 0.003*"bitch" + 0.003*"world" + 0.003*"uh" + 0.003*"love" + 0.003*"money" + 0.002*"black" + 0.002*"mean" + 0.002*"day" + 0.002*"time"
# 2018-05-30 14:53:48,121 : INFO : topic #1 (0.500): 0.005*"everybody" + 0.004*"give" + 0.003*"think" + 0.003*"mind" + 0.003*"everything" + 0.003*"boy" + 0.003*"god" + 0.003*"ever" + 0.003*"people" + 0.003*"finna"
# [(0,
#   '0.003*"good" + 0.003*"bitch" + 0.003*"world" + 0.003*"uh" + 0.003*"love" + 0.003*"money" + 0.002*"black" + 0.002*"mean" + 0.002*"day" + 0.002*"time"'),
#  (1,
#   '0.005*"everybody" + 0.004*"give" + 0.003*"think" + 0.003*"mind" + 0.003*"everything" + 0.003*"boy" + 0.003*"god" + 0.003*"ever" + 0.003*"people" + 0.003*"finna"')]

# %%
#Keep adding more phrases/words to stopwords and look at both (1,2) and (2,3) for ngram_range

# %%
#1 --> young sinatra (young, working hard, and making a name for himself)
#2 --> logic (positivity, love, change)
#3 --> bobby tarantino (the party/turn up alter-ego of Logic, party, girls, fun, cocky)
